# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
heat_solutions = np.loadtxt('results_heat.dat', unpack=True)

# %%
for sol in heat_solutions:
    plt.plot(sol)
plt.show()

# %%
wave_solutions = np.loadtxt('results_wave.dat', unpack=True)

# %%
for sol in wave_solutions[:-3]:
    plt.plot(sol)
plt.show()
